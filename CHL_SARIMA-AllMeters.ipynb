# %% [markdown]
# ### https://towardsdatascience.com/how-to-forecast-sales-with-python-using-sarima-model-ba600992fa7d

# %%
import warnings
import itertools
import numpy as np
from numpy import concatenate, savetxt, unique, array, subtract
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
from pandas import merge, DataFrame, Series
import statsmodels.api as sm
import matplotlib
from math import sqrt
from statistics import mean
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'g'

# %%
df = pd.read_csv('CharlestownAllWithDate1.csv', header=0, sep='[,]', parse_dates=True, squeeze=True, dayfirst=True, engine='python')
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
y = df.set_index(['Date'])

# %%
meter_ids = unique(y['MeterNo'])
#print(meter_ids)
prediction_d = dict()
actual_d = dict()
results_RMSE = dict()
results_Error = dict()
prediction_df = []
actual_df = []
results_dfRMSE = []
results_dfError = []
results_df = []
pred_date = '2021-02-01'

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter for SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter for SARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False, period=1)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param,param_seasonal,results.aic))
        except: 
            continue

# %%
for m in meter_ids:
    df = pd.read_csv('CharlestownAllWithDate1.csv', header=0, sep='[,]', parse_dates=True, squeeze=True, dayfirst=True, engine='python')
    df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
    y = df.set_index(['Date'])
    y = y.loc[y['MeterNo'] == m]
    y.drop(y.columns[[1]], axis = 1, inplace = True)
    #print(y)
    mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
    results = mod.fit()
    pred = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=False)
    y_forecasted = pred.predicted_mean
    y_truth = y[pred_date:]
    prediction = y_forecasted.mean()
    actual = y_truth.mean()
    error = (prediction - actual)
    mse = (error **2)
    rmse = round(np.sqrt(mse),2)
    print('MeterNo %s - Prediction: %.3f - Actual: %.3f - Test Error: %.3f - Test RMSE: %.3f' % (m, prediction, actual, error, rmse))
    results_RMSE[m] = rmse #dict
    results_Error[m] = error #dict
    prediction_d[m] = prediction #dict
    actual_d[m] = actual #dict
    results_dfRMSE.append([m, mean(rmse)]) #array
    results_dfError.append([m, mean(error)]) #array
    prediction_df.append([m, prediction]) #array
    actual_df.append([m, mean(actual)]) #array
# Out:
# MeterNo 1.0 - Prediction: 7.066 - Actual: 6.829 - Test Error: 0.237 - Test RMSE: 0.240
# MeterNo 2.0 - Prediction: 25.353 - Actual: 24.500 - Test Error: 0.853 - Test RMSE: 0.850
# MeterNo 3.0 - Prediction: 16.493 - Actual: 16.114 - Test Error: 0.379 - Test RMSE: 0.380
# MeterNo 4.0 - Prediction: 16.929 - Actual: 16.471 - Test Error: 0.457 - Test RMSE: 0.460
# MeterNo 5.0 - Prediction: 4.166 - Actual: 4.086 - Test Error: 0.080 - Test RMSE: 0.080
# MeterNo 6.0 - Prediction: 13.897 - Actual: 12.371 - Test Error: 1.525 - Test RMSE: 1.530
# MeterNo 281.0 - Prediction: 25.175 - Actual: 24.529 - Test Error: 0.647 - Test RMSE: 0.650
# MeterNo 282.0 - Prediction: 22.147 - Actual: 21.386 - Test Error: 0.761 - Test RMSE: 0.760
# MeterNo 283.0 - Prediction: 1.618 - Actual: 0.000 - Test Error: 1.618 - Test RMSE: 1.620
# MeterNo 284.0 - Prediction: 16.564 - Actual: 15.114 - Test Error: 1.450 - Test RMSE: 1.450
# MeterNo 285.0 - Prediction: 45.042 - Actual: 43.800 - Test Error: 1.242 - Test RMSE: 1.240
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-d9bc89dc4534> in <module>
#      11                                 enforce_stationarity=False,
#      12                                 enforce_invertibility=False)
# ---> 13     results = mod.fit()
#      14     pred = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=False)
#      15     y_forecasted = pred.predicted_mean
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     712             else:
#     713                 func = self.smooth
# --> 714             res = func(mlefit.params, transformed=False, includes_fixed=False,
#     715                        cov_type=cov_type, cov_kwds=cov_kwds)
#     716
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in smooth(self, params, transformed, includes_fixed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     873
#     874         # Wrap in a results object
# --> 875         return self._wrap_results(params, result, return_ssm, cov_type,
#     876                                   cov_kwds, results_class,
#     877                                   results_wrapper_class)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _wrap_results(self, params, result, return_raw, cov_type, cov_kwds, results_class, wrapper_class)
#     772                 wrapper_class = self._res_classes['fit'][1]
#     773
# --> 774             res = results_class(self, params, result, **result_kwargs)
#     775             result = wrapper_class(res)
#     776         return result
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in __init__(self, model, params, filter_results, cov_type, **kwargs)
#    1797     def __init__(self, model, params, filter_results, cov_type=None,
#    1798                  **kwargs):
# -> 1799         super(SARIMAXResults, self).__init__(model, params, filter_results,
#    1800                                              cov_type, **kwargs)
#    1801
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in __init__(self, model, params, results, cov_type, cov_kwds, **kwargs)
#    2359             self._states.predicted = None
#    2360         elif use_pandas:
# -> 2361             extended_index = self.model._get_index_with_final_state()
#    2362             self._states.predicted = pd.DataFrame(
#    2363                 self.predicted_state.T, index=extended_index, columns=columns)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _get_index_with_final_state(self)
#     205             if isinstance(self._index, pd.DatetimeIndex):
#     206                 index = pd.date_range(
# --> 207                     start=self._index[0], periods=len(self._index) + 1,
#     208                     freq=self._index.freq)
#     209             elif isinstance(self._index, pd.PeriodIndex):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\extension.py in __getitem__(self, key)
#     213
#     214     def __getitem__(self, key):
# --> 215         result = self._data[key]
#     216         if isinstance(result, type(self._data)):
#     217             if result.ndim == 1:
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in __getitem__(self, key)
#     536         if lib.is_integer(key):
#     537             # fast-path
# --> 538             result = self._data[key]
#     539             if self.ndim == 1:
#     540                 return self._box_func(result)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
prediction_df=DataFrame(prediction_df)
prediction_df.columns = ['MeterID', 'Prediction']
print(prediction_df)
# Out:
#      MeterID  Prediction
# 0        1.0    7.066052
# 1        2.0   25.352763
# 2        3.0   16.493191
# 3        4.0   16.928545
# 4        5.0    4.166146
# ..       ...         ...
# 279    281.0   25.175114
# 280    282.0   22.147112
# 281    283.0    1.617809
# 282    284.0   16.564455
# 283    285.0   45.041791
#
# [284 rows x 2 columns]

# %%
actual_df=DataFrame(actual_df)
actual_df.columns = ['MeterID', 'Actual']
print(actual_df)
# Out:
#      MeterID     Actual
# 0        1.0   6.828571
# 1        2.0  24.500000
# 2        3.0  16.114286
# 3        4.0  16.471429
# 4        5.0   4.085714
# ..       ...        ...
# 279    281.0  24.528571
# 280    282.0  21.385714
# 281    283.0   0.000000
# 282    284.0  15.114286
# 283    285.0  43.800000
#
# [284 rows x 2 columns]

# %%
results_dfRMSE=DataFrame(results_dfRMSE)
results_dfRMSE.columns = ['MeterID', 'RMSE']
print(results_dfRMSE)
# Out:
#      MeterID  RMSE
# 0        1.0  0.24
# 1        2.0  0.85
# 2        3.0  0.38
# 3        4.0  0.46
# 4        5.0  0.08
# ..       ...   ...
# 279    281.0  0.65
# 280    282.0  0.76
# 281    283.0  1.62
# 282    284.0  1.45
# 283    285.0  1.24
#
# [284 rows x 2 columns]

# %%
results_dfError=DataFrame(results_dfError)
results_dfError.columns = ['MeterID', 'Error']
print(results_dfError)
# Out:
#      MeterID     Error
# 0        1.0  0.237481
# 1        2.0  0.852763
# 2        3.0  0.378905
# 3        4.0  0.457117
# 4        5.0  0.080431
# ..       ...       ...
# 279    281.0  0.646542
# 280    282.0  0.761397
# 281    283.0  1.617809
# 282    284.0  1.450170
# 283    285.0  1.241791
#
# [284 rows x 2 columns]

# %%
results_df = merge(actual_df, prediction_df, on="MeterID", how='left')
results_df = merge(results_df, results_dfRMSE, on="MeterID", how='left')
results_df = merge(results_df, results_dfError, on="MeterID", how='left')
print(results_df)
# Out:
#      MeterID     Actual  Prediction  RMSE     Error
# 0        1.0   6.828571    7.066052  0.24  0.237481
# 1        2.0  24.500000   25.352763  0.85  0.852763
# 2        3.0  16.114286   16.493191  0.38  0.378905
# 3        4.0  16.471429   16.928545  0.46  0.457117
# 4        5.0   4.085714    4.166146  0.08  0.080431
# ..       ...        ...         ...   ...       ...
# 279    281.0  24.528571   25.175114  0.65  0.646542
# 280    282.0  21.385714   22.147112  0.76  0.761397
# 281    283.0   0.000000    1.617809  1.62  1.617809
# 282    284.0  15.114286   16.564455  1.45  1.450170
# 283    285.0  43.800000   45.041791  1.24  1.241791
#
# [284 rows x 5 columns]

# %%
results_df.drop(results_df.columns[[0]], axis = 1, inplace = True)

# %%
def Summary(x):
    return Series(index=['min','max', 'mean','sum'],data=[x.min(),x.max(),x.mean(),x.sum()])
results_df.apply(Summary)
# Out:
#            Actual   Prediction        RMSE      Error
# min      0.000000    -0.408818    0.000000  -0.561570
# max     56.528571    57.362911    1.620000   1.617809
# mean    16.148767    16.470172    0.376796   0.321406
# sum   4586.249762  4677.528990  107.010000  91.279228
